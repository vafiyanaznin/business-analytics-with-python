# %% [markdown]
# <a href="https://colab.research.google.com/github/vafiyanaznin/business-analytics-with-python/blob/main/REV9%20Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Supermarket_sales.csv")
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
a=df.loc[(df["City"]=="Yangon")]
a["Tax"].max()
# Out:
# 49.49

# %%
a=df.loc[(df["City"]=="Yangon")]
b=df.loc[(df["City"]=="Mandalay")]
print(a["Total"].sum())
print(b["Total"].sum())
# Out:
# 106200.3705
# 106197.67199999999

# %%
a=df.loc[(df["City"]=="Yangon")]
z=a.groupby("Productline").min()
print(z["Quantity"].min())
# Out:
# 1

# %%
import matplotlib.pyplot as plt
x=df["Tax"]
y=df["Unitprice"]
plt.scatter(x,y)

# %%
a=df["gross_margin_percentage"].max()
print(a)
# Out:
# 4.761904762

# %%
df.loc[df["gross_margin_percentage"]==a]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
a=df.loc[df["Gender"]=="Male"]
b=df.loc[df["Gender"]=="Female"]
z=a["gross_iincome"].max()
y=b["gross_iincome"].max()
if y>z:
    print("Female has a higher profit margin")
else:
    print("Male has a higher profit margin")
# Out:
# Female has a higher profit margin

# %%
df.groupby("Customertype").max()
# Out:
#                 No    InvoiceID Branch    City Gender        Productline  \
# Customertype
# Member        1000  895-66-0685      C  Yangon   Male  Sports and travel
# Normal         999  898-04-2717      C  Yangon   Male  Sports and travel
#
#               Unitprice  Quantity    Tax    Total      Date   Time  Payment  \
# Customertype
# Member            99.96        10  49.65  1042.65  3/9/2019  20:59  Ewallet
# Normal            99.96        10  49.49  1039.29  3/9/2019  20:59  Ewallet
#
#                cogs  gross_margin_percentage  gross_iincome  Rating
# Customertype
# Member        993.0                 4.761905          49.65    10.0
# Normal        989.8                 4.761905          49.49    10.0

# %%
a=df.groupby("InvoiceID").min()
print(a["gross_iincome"].min())
# Out:
# 0.5085

# %%
import matplotlib.pyplot as plt
x=df["Rating"]
y=df["Unitprice"]
plt.scatter(x,y)

# %%
a=df.gross_iincome.max()
a
df.Branch.loc[(df["gross_iincome"]==a)]
# Out:
# 350    C
# Name: Branch, dtype: object

# %%
df.City.loc[(df["gross_iincome"]==a)]
# Out:
# 350    Naypyitaw
# Name: City, dtype: object

# %%
b=df.Rating.max()
b
df.City.loc[(df["Rating"]==b)]
# Out:
# 60     Naypyitaw
# 62      Mandalay
# 159     Mandalay
# 387       Yangon
# 853     Mandalay
# Name: City, dtype: object
